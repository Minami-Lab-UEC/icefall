# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
pd.options.display.float_format = '{:.17f}'.format

# %%
tsv_path = "data/combined_results.tsv"
source_types = [
    "frame_count",
    "token_count"
]
source_types += [f"{n}gram" for n in [1,2,3,4,5]]

# %%
result_tsv = pd.read_csv(tsv_path, delimiter='\t')

# %%
approx_res = {
    'type': [],
    'slope': [],
    'fitness': [],
}

# %%
for type in source_types:
    approx_res['type'].append(type)
    slope, *_ = np.linalg.lstsq(
        result_tsv[type].to_numpy()[:, None],
        result_tsv["word_count"],
        rcond=None
    )
    slope = float(slope)
    approx_res["slope"].append(slope)
    approx = slope * result_tsv[type]
    approx_res["fitness"].append(
        ((approx - result_tsv["word_count"]) ** 2).mean()
    )
# Out:
# /tmp/ipykernel_26472/1521461559.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   slope = float(slope)

# %%
approx_res_df = pd.DataFrame(approx_res)
approx_res_df
# Out:
#           type               slope              fitness
# 0  frame_count 0.10918277484868487 35.02255092164992334
# 1  token_count 0.50437623996984593 28.12824912888678952
# 2        1gram 0.21428022865333540 23.44945777736481674
# 3        2gram 0.28089988989667980 27.38664461495917735
# 4        3gram 0.36376589909469687 24.87669487579582395
# 5        4gram 0.45542393511953849 24.43501584435481888
# 6        5gram 0.50731459230278320 28.75120610906996887

# %%
def plot_approx(type : str):
    plt.scatter(result_tsv[type], result_tsv["word_count"], s=1)
    plt.plot(
        [0, 100 / approx_res["slope"][source_types.index(type)]],
        [0, 100],
        # approx_res["slope"][source_types.index(type)] * result_tsv[type],
        color='r',
    )
    plt.xlabel(type)
    plt.ylabel('word_count')
    plt.show()

# %%
plot_approx("frame_count")

# %%
plot_approx("token_count")

# %%
plot_approx("1gram")

# %%
plot_approx("2gram")

# %%
plot_approx("3gram")

# %%
plot_approx("4gram")

# %%
plot_approx("5gram")
